# %%
# Dependencies and Setup.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# CSV Path
data = "Resources/time_series_covid19_confirmed_global.csv"

# %%
# Creating a variable for the DF.
covid_df = pd.read_csv(data)

# %%
# Looking at the data to see what needs to go. I notice that numbers posted under each date are a rolling count, 
# therefore all I need is the most recent date (9/14/20) to get the current number of cases per country.
covid_df.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/5/20  9/6/20  \
# ...

# %%
# Deleting columns I don't need.
essentials_df = covid_df[["Country/Region", "9/14/20"]]
essentials_df.head(20)
# Out:
#          Country/Region  9/14/20
# 0           Afghanistan    38772
# 1               Albania    11520
# 2               Algeria    48496
# 3               Andorra     1438
# 4                Angola     3439
# 5   Antigua and Barbuda       95
# 6             Argentina   565446
# 7               Armenia    45969
# 8             Australia      113
# 9             Australia     4177
# 10            Australia       33
# 11            Australia     1150
# 12            Australia      466
# 13            Australia      230
# 14            Australia    19911
# 15            Australia      659
# 16              Austria    33541
# 17           Azerbaijan    38403
# 18              Bahamas     3008
# 19              Bahrain    60965

# %%
# The problem we have above is the duplicate countries which are divided by state/province. We need those combined
# and summed together. 
summed_df = essentials_df.groupby(['Country/Region']).sum()
summed_df.head(20)
# Out:
#                      9/14/20
# Country/Region
# Afghanistan            38772
# Albania                11520
# Algeria                48496
# Andorra                 1438
# Angola                  3439
# Antigua and Barbuda       95
# Argentina             565446
# Armenia                45969
# Australia              26739
# Austria                33541
# Azerbaijan             38403
# Bahamas                 3008
# Bahrain                60965
# Bangladesh            339332
# Barbados                 183
# Belarus                74360
# Belgium                94306
# Belize                  1501
# Benin                   2267
# Bhutan                   245

# %%
# Renaming columns to reflect the data
clean_df = summed_df.rename(columns={'9/14/20': "Total COVID-19 Cases (9/14/20)"})
clean_df.head(30)
# Out:
#                         Total COVID-19 Cases (9/14/20)
# Country/Region
# Afghanistan                                      38772
# Albania                                          11520
# Algeria                                          48496
# Andorra                                           1438
# Angola                                            3439
# Antigua and Barbuda                                 95
# Argentina                                       565446
# Armenia                                          45969
# Australia                                        26739
# Austria                                          33541
# Azerbaijan                                       38403
# Bahamas                                           3008
# Bahrain                                          60965
# Bangladesh                                      339332
# Barbados                                           183
# Belarus                                          74360
# ...

# %%
# Pushing the cleaned DF to a CSV file
clean_df.to_csv("Resources/cleaned_covid_cases.csv")
